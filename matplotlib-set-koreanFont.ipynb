# %% [markdown]
# Ubuntu Linux
# https://financedata.github.io/posts/matplotlib-hangul-for-ubuntu-linux.html
#
# Window Anaconda
# https://financedata.github.io/posts/matplotlib-hangul-for-windows-anaconda.html

# %%
# 실행중인 운영체제 확인

import platform
platform.platform()
# Out:
# 'Linux-4.15.0-128-generic-x86_64-with-glibc2.10'

# %%
# matplotlib 주요 설치 정보

import matplotlib

print ('버전: ', matplotlib.__version__)
print ('설치위치: ', matplotlib.__file__)
print ('설정: ', matplotlib.get_configdir())
print ('캐시: ', matplotlib.get_cachedir())
# Out:
# 버전:  3.3.2
# 설치위치:  /home/jason/anaconda3/envs/stock/lib/python3.8/site-packages/matplotlib/__init__.py
# 설정:  /home/jason/.config/matplotlib
# 캐시:  /home/jason/.cache/matplotlib

# %%
#matplotlib 기본 설정

# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (14,4)

# %% [markdown]
# ### 글꼴 설치

# %% [markdown]
# ```
# $ sudo apt-get install fonts-nanum*
# $ sudo fc-cache -fv
#
# $ sudo cp new_font.ttf /usr/share/fonts/
# $ sudo fc-cache -fv
#
#
# $ sudo cp /usr/share/fonts/truetype/nanum/Nanum* /usr/local/lib/python3.4/dist-packages/matplotlib/mpl-data/fonts/ttf/
# $ rm -rf /home/ubuntu/.cache/matplotlib/*
#
#
# ls -l /usr/share/fonts/truetype/
#
#
# ls -l /usr/share/fonts/truetype/nanum/
# ```

# %% [markdown]
# ## 사용 가능한 ttf 폰트 목록

# %%
import matplotlib
import matplotlib.font_manager

[f.name for f in matplotlib.font_manager.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# ['NanumMyeongjo',
#  'NanumBarunGothic',
#  'NanumMyeongjo Eco',
#  'NanumSquare',
#  'NanumGothicCoding',
#  'NanumGothic Eco',
#  'NanumGothic',
#  'NanumMyeongjo Eco',
#  'NanumMyeongjo Eco',
#  'NanumBarunpen',
#  'Nanum Pen Script',
#  'NanumSquareRound',
#  'NanumBarunGothic',
#  'NanumSquare',
#  'NanumGothic',
#  'Nanum Brush Script',
#  'NanumGothicCoding',
#  'NanumSquareRound',
#  'NanumSquareRound',
#  'NanumBarunGothic',
#  'NanumBarunGothic',
#  'NanumGothic',
#  'NanumGothic Eco',
#  'NanumMyeongjo',
#  'NanumBarunpen',
#  'NanumSquare',
#  'NanumSquare',
#  'NanumGothic',
#  'NanumMyeongjo',
#  'NanumSquareRound',
#  'NanumGothic Eco',
#  'NanumSquareRound',
#  'NanumMyeongjo',
#  'NanumMyeongjo Eco',
#  'NanumBarunpen',
#  'NanumSquareRound',
#  'NanumGothic Eco',
#  'NanumSquare',
#  'NanumBarunGothic',
#  'NanumGothic Eco',
#  'NanumBarunGothic',
#  'NanumGothicCoding',
#  'NanumGothicCoding',
#  'NanumMyeongjo Eco',
#  'NanumGothic',
#  'Nanum Pen Script',
#  'NanumSquare',
#  'NanumMyeongjo',
#  'NanumBarunpen',
#  'NanumGothic Eco',
#  'NanumMyeongjo',
#  'NanumBarunGothic',
#  'Nanum Brush Script',
#  'NanumSquareRound',
#  'NanumSquareRound',
#  'NanumGothic',
#  'NanumSquare',
#  'NanumBarunGothic',
#  'NanumGothic',
#  'NanumMyeongjo Eco',
#  'NanumGothic',
#  'NanumSquare']

# %% [markdown]
# ## matplotlib에 새로운 폰트를 추가하기

# %% [markdown]
# 1. ttf 폰트를 matplotlib으로 복사한다
#    (아나콘다를 사용하는 경우 보통 아래 디렉토리이다. jason는 사용자 이름)
#
#     conda 환경
#     `~/anaconda3/envs/stock/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf`
#
#     ubuntu linux 환경
#     `/usr/local/lib/python3.4/dist-packages/matplotlib/mpl-data/fonts/ttf/
#     `
#
#
# 2. matplotlib cache 폴더의 내용 삭제한다
#
#
#
# 3. **커널 재시작(주피터 노트북 재시작)**

# %% [markdown]
# ## 텍스트 출력시 폰트 특성을 지정¶

# %%
import numpy as np

data = np.random.randint(-100, 100, 50).cumsum()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

path = '/usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf'
fontprop = fm.FontProperties(fname=path, size=18)

plt.plot(range(50), data, 'r')
plt.title('가격변동 추이', fontproperties=fontprop)
plt.ylabel('가격', fontproperties=fontprop)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

path_gothic = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop1 = fm.FontProperties(fname=path_gothic, size=20)

path_pen = '/usr/share/fonts/truetype/nanum/NanumPen.ttf'
fontprop2 = fm.FontProperties(fname=path_pen, size=34)

plt.plot(range(50), data, 'r')
plt.ylabel('가격', fontproperties=fontprop1)
plt.title('가격변동 추이', fontproperties=fontprop2)
plt.show()

# %%
path = '/usr/share/fonts/truetype/nanum/NanumPen.ttf'
prop = fm.FontProperties(fname=path, size=18)

fig, ax = plt.subplots()
ax.plot(data)
ax.set_title('가격 변화 (나눔고딕코딩)', fontproperties=prop)

plt.show()

# %% [markdown]
# ## 전역 글꼴 설정: matplotlib.rcParams[]

# %%
# 기본 설정 읽기
import matplotlib.pyplot as plt

# size, family
print (plt.rcParams['font.size'] ) 
print (plt.rcParams['font.family'] )
# Out:
# 10.0
# ['sans-serif']

# %%
# serif, sans-serif, monospace
print (plt.rcParams['font.serif']) 
print (plt.rcParams['font.sans-serif']) 
print (plt.rcParams['font.monospace'])
# Out:
# ['DejaVu Serif', 'Bitstream Vera Serif', 'Computer Modern Roman', 'New Century Schoolbook', 'Century Schoolbook L', 'Utopia', 'ITC Bookman', 'Bookman', 'Nimbus Roman No9 L', 'Times New Roman', 'Times', 'Palatino', 'Charter', 'serif']
# ['DejaVu Sans', 'Bitstream Vera Sans', 'Computer Modern Sans Serif', 'Lucida Grande', 'Verdana', 'Geneva', 'Lucid', 'Arial', 'Helvetica', 'Avant Garde', 'sans-serif']
# ['DejaVu Sans Mono', 'Bitstream Vera Sans Mono', 'Computer Modern Typewriter', 'Andale Mono', 'Nimbus Mono L', 'Courier New', 'Courier', 'Fixed', 'Terminal', 'monospace']

# %% [markdown]
# #### 폰트의 기본값들을 다음과 같이 설정할 수 있다

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = 'NanumGothic'
plt.rcParams['font.size'] = 12.
plt.rcParams['xtick.labelsize'] = 24.
plt.rcParams['ytick.labelsize'] = 24.
plt.rcParams['axes.labelsize'] = 20.

plt.title('가격의 변화')
plt.plot(range(50), data, 'r')
plt.show()
# Out:
# /home/jason/anaconda3/envs/stock/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/jason/anaconda3/envs/stock/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = 'NanumGothic'
plt.rcParams["font.size"] = 12
plt.rcParams["figure.figsize"] = (14,4)

plt.title('가격의 변화')
plt.plot(range(50), data, 'r')
plt.show()
# Out:
# /home/jason/anaconda3/envs/stock/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/jason/anaconda3/envs/stock/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = 'NanumGothicCoding'
plt.rcParams["font.size"] = 12
plt.rcParams['xtick.labelsize'] = 12.
plt.rcParams['ytick.labelsize'] = 12.
plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams['axes.grid'] = True 
plt.rcParams['axes.unicode_minus'] = False

plt.title('가격의 변화')
plt.plot(range(50), data, 'r')
plt.show()

# %% [markdown]
# ## ttf 파일에서 폰트 이름 얻어 전역 설정
#
# #### "font.family"에 지정할 이름을 .ttf 파일로 부터 얻을 수 있다

# %%
from matplotlib import font_manager, rc

font_fname = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font_name = font_manager.FontProperties(fname=font_fname).get_name()

rc('font', family=font_name)
print(font_name)
# Out:
# NanumGothic

# %%
plt.title('가격의 변화')
plt.plot(range(50), data, 'r')
plt.show()
